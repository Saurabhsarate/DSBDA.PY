# %%
import numpy as np
import pandas as pd
df =pd.read_csv("StudentPerformance.csv")
df
# Out:
#     Gender  Math_score  Reading_score Wrirting_score  Placement_scor  \
# 0   female        80.0             94             61            77.0
# 1   female        60.0             92             80            73.0
# 2     male        75.0             84             61            81.0
# 3     male        90.0             84             73            83.0
# 4   female        63.0              0             71            97.0
# 5     male        60.0             80              0           102.0
# 6     male        60.0             94             72            82.0
# 7   female        77.0             79             69            96.0
# 8     male        69.0             78             74            75.0
# 9     male        72.0             94             77            86.0
# 10  female        77.0             77             59             NaN
# 11    male        71.0             99             70            83.0
# 12    male        74.0              0             79            96.0
# ...

# %%
df.isnull()
# Out:
#     Gender  Math_score  Reading_score  Wrirting_score  Placement_scor  \
# 0    False       False          False           False           False
# 1    False       False          False           False           False
# 2    False       False          False           False           False
# 3    False       False          False           False           False
# 4    False       False          False           False           False
# 5    False       False          False           False           False
# 6    False       False          False           False           False
# 7    False       False          False           False           False
# 8    False       False          False           False           False
# 9    False       False          False           False           False
# 10   False       False          False           False            True
# 11   False       False          False           False           False
# ...

# %%
series = pd.isnull(df["Math_score"])
df[series]
# Out:
#     Gender  Math_score  Reading_score Wrirting_score  Placement_scor  \
# 21  female         NaN             89             70            92.0
#
#     Club_join_date  Placement_offer_count Region
# 21            2019                      3   Pune

# %%
df.notnull()
# Out:
#     Gender  Math_score  Reading_score  Wrirting_score  Placement_scor  \
# 0     True        True           True            True            True
# 1     True        True           True            True            True
# 2     True        True           True            True            True
# 3     True        True           True            True            True
# 4     True        True           True            True            True
# 5     True        True           True            True            True
# 6     True        True           True            True            True
# 7     True        True           True            True            True
# 8     True        True           True            True            True
# 9     True        True           True            True            True
# 10    True        True           True            True           False
# 11    True        True           True            True            True
# ...

# %%
series1 = pd.notnull(df["Math_score"])
df[series1]
# Out:
#     Gender  Math_score  Reading_score Wrirting_score  Placement_scor  \
# 0        0        80.0             94             61            77.0
# 1        0        60.0             92             80            73.0
# 2        1        75.0             84             61            81.0
# 3        1        90.0             84             73            83.0
# 4        0        63.0              0             71            97.0
# 5        1        60.0             80              0           102.0
# 6        1        60.0             94             72            82.0
# 7        0        77.0             79             69            96.0
# 8        1        69.0             78             74            75.0
# 9        1        72.0             94             77            86.0
# 10       0        77.0             77             59             NaN
# 11       1        71.0             99             70            83.0
# 12       1        74.0              0             79            96.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])
newdf = df
df
# Out:
#     Gender  Math_score  Reading_score Wrirting_score  Placement_scor  \
# 0        0        80.0             94             61            77.0
# 1        0        60.0             92             80            73.0
# 2        1        75.0             84             61            81.0
# 3        1        90.0             84             73            83.0
# 4        0        63.0              0             71            97.0
# 5        1        60.0             80              0           102.0
# 6        1        60.0             94             72            82.0
# 7        0        77.0             79             69            96.0
# 8        1        69.0             78             74            75.0
# 9        1        72.0             94             77            86.0
# 10       0        77.0             77             59             NaN
# 11       1        71.0             99             70            83.0
# 12       1        74.0              0             79            96.0
# ...

# %%
missing_values = ["Na","na"]
df = pd.read_csv("StudentPerformance.csv", na_values = missing_values)
df
# Out:
#     Gender  Math_score  Reading_score  Wrirting_score  Placement_scor  \
# 0   female        80.0             94            61.0            77.0
# 1   female        60.0             92            80.0            73.0
# 2     male        75.0             84            61.0            81.0
# 3     male        90.0             84            73.0            83.0
# 4   female        63.0              0            71.0            97.0
# 5     male        60.0             80             0.0           102.0
# 6     male        60.0             94            72.0            82.0
# 7   female        77.0             79            69.0            96.0
# 8     male        69.0             78            74.0            75.0
# 9     male        72.0             94            77.0            86.0
# 10  female        77.0             77            59.0             NaN
# 11    male        71.0             99            70.0            83.0
# ...

# %%
ndf = df
ndf.fillna(0)
# Out:
#     Gender  Math_score  Reading_score  Wrirting_score  Placement_scor  \
# 0   female        80.0             94            61.0            77.0
# 1   female        60.0             92            80.0            73.0
# 2     male        75.0             84            61.0            81.0
# 3     male        90.0             84            73.0            83.0
# 4   female        63.0              0            71.0            97.0
# 5     male        60.0             80             0.0           102.0
# 6     male        60.0             94            72.0            82.0
# 7   female        77.0             79            69.0            96.0
# 8     male        69.0             78            74.0            75.0
# 9     male        72.0             94            77.0            86.0
# 10  female        77.0             77            59.0             0.0
# 11    male        71.0             99            70.0            83.0
# ...

# %%
df['Math_score'] = df['Math_score'].fillna(df['Math_score'].mean())

# %%
df
# Out:
#     Gender  Math_score  Reading_score  Wrirting_score  Placement_scor  \
# 0   female   80.000000             94            61.0            77.0
# 1   female   60.000000             92            80.0            73.0
# 2     male   75.000000             84            61.0            81.0
# 3     male   90.000000             84            73.0            83.0
# 4   female   63.000000              0            71.0            97.0
# 5     male   60.000000             80             0.0           102.0
# 6     male   60.000000             94            72.0            82.0
# 7   female   77.000000             79            69.0            96.0
# 8     male   69.000000             78            74.0            75.0
# 9     male   72.000000             94            77.0            86.0
# 10  female   77.000000             77            59.0             NaN
# 11    male   71.000000             99            70.0            83.0
# ...

# %%
df['Reading_score'] = df['Reading_score'].fillna(df['Reading_score'].median())

# %%
df
# Out:
#     Gender  Math_score  Reading_score  Wrirting_score  Placement_scor  \
# 0   female   80.000000             94            61.0            77.0
# 1   female   60.000000             92            80.0            73.0
# 2     male   75.000000             84            61.0            81.0
# 3     male   90.000000             84            73.0            83.0
# 4   female   63.000000              0            71.0            97.0
# 5     male   60.000000             80             0.0           102.0
# 6     male   60.000000             94            72.0            82.0
# 7   female   77.000000             79            69.0            96.0
# 8     male   69.000000             78            74.0            75.0
# 9     male   72.000000             94            77.0            86.0
# 10  female   77.000000             77            59.0             NaN
# 11    male   71.000000             99            70.0            83.0
# ...

# %%
m_v = df['Math_score'].mean()
df['Math_score'].fillna(value = m_v, inplace = True  )
df
# Out:
#     Gender  Math_score  Reading_score  Wrirting_score  Placement_scor  \
# 0   female   80.000000             94            61.0            77.0
# 1   female   60.000000             92            80.0            73.0
# 2     male   75.000000             84            61.0            81.0
# 3     male   90.000000             84            73.0            83.0
# 4   female   63.000000              0            71.0            97.0
# 5     male   60.000000             80             0.0           102.0
# 6     male   60.000000             94            72.0            82.0
# 7   female   77.000000             79            69.0            96.0
# 8     male   69.000000             78            74.0            75.0
# 9     male   72.000000             94            77.0            86.0
# 10  female   77.000000             77            59.0             NaN
# 11    male   71.000000             99            70.0            83.0
# ...

# %%
ndf.replace(to_replace = np.nan,value = -99)
# Out:
#     Gender  Math_score  Reading_score  Wrirting_score  Placement_scor  \
# 0   female   80.000000             94            61.0            77.0
# 1   female   60.000000             92            80.0            73.0
# 2     male   75.000000             84            61.0            81.0
# 3     male   90.000000             84            73.0            83.0
# 4   female   63.000000              0            71.0            97.0
# 5     male   60.000000             80             0.0           102.0
# 6     male   60.000000             94            72.0            82.0
# 7   female   77.000000             79            69.0            96.0
# 8     male   69.000000             78            74.0            75.0
# 9     male   72.000000             94            77.0            86.0
# 10  female   77.000000             77            59.0           -99.0
# 11    male   71.000000             99            70.0            83.0
# ...

# %%
ndf.dropna()
# Out:
#     Gender  Math_score  Reading_score  Wrirting_score  Placement_scor  \
# 0   female   80.000000             94            61.0            77.0
# 1   female   60.000000             92            80.0            73.0
# 3     male   90.000000             84            73.0            83.0
# 4   female   63.000000              0            71.0            97.0
# 5     male   60.000000             80             0.0           102.0
# 6     male   60.000000             94            72.0            82.0
# 8     male   69.000000             78            74.0            75.0
# 9     male   72.000000             94            77.0            86.0
# 11    male   71.000000             99            70.0            83.0
# 12    male   74.000000              0            79.0            96.0
# 13    male   70.000000             88            75.0            93.0
# 14  female   64.000000             75            62.0            97.0
# ...

# %%
#baki same aheyt

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
col=['Math_score','Reading_score','Wrirting_score','Placement_scor'] 
df.boxplot(col)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 3
#       1 import matplotlib.pyplot as plt
#       2 col=['Math_score','Reading_score','Wrirting_score','Placement_scor']
# ----> 3 df.boxplot(col)
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:516, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     499 @Substitution(backend=_backend_doc)
#     500 @Appender(_boxplot_doc)
#     501 def boxplot_frame(
#    (...)
#     513     **kwargs,
#     514 ):
#     515     plot_backend = _get_plot_backend(backend)
# --> 516     return plot_backend.boxplot_frame(
#     517         self,
#     518         column=column,
#     519         by=by,
#     520         ax=ax,
#     521         fontsize=fontsize,
#     522         rot=rot,
#     523         grid=grid,
#     524         figsize=figsize,
# ...

# %%
import matplotlib.pyplot as plt

# %%
col=['Math_score','Reading_score', 'Placement_scor'] 
df.boxplot(col)
plt.show()

# %%
print(np.where(df['Math_score']>90))
# Out:
# (array([], dtype=int64),)

# %%
sorted_rscore=sorted(df['Reading_score'])
sorted_rscore
# Out:
# [0,
#  0,
#  75,
#  76,
#  77,
#  78,
#  78,
#  79,
#  79,
#  80,
#  80,
#  80,
#  80,
#  82,
#  83,
#  84,
#  84,
#  87,
#  88,
#  88,
#  89,
#  90,
#  91,
#  92,
#  92,
#  94,
#  94,
#  94,
#  95,
#  99]

# %%
q1=np.percentile(sorted_rscore,25)
q3=np.percentile(sorted_rscore,75)
print(q1,q3)
# Out:
# 79.0 90.75

# %%
IQR=q3-q1
IQR
# Out:
# 11.75

# %%
lwr_bound=q1-(1.5*IQR)
upr_bound=q3+(1.5*IQR)
print(lwr_bound,upr_bound)
# Out:
# 61.375 108.375

# %%
r_outliers=[]
for i in sorted_rscore:
    if(i<lwr_bound or i>upr_bound):
        r_outliers.append(i)
print(r_outliers)
# Out:
# [0, 0]
